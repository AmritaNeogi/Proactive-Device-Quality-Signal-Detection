# %% [markdown]
# # 03 – Data Loading & Basic Cleaning
#
# This notebook loads the raw mobile reviews dataset, performs initial profiling and light cleaning, and saves a clean CSV that we will later use for:
# - NLP-based complaint flagging
# - Weekly aggregations
# - Anomaly detection and Tableau dashboards

# %% [markdown]
# ### 1. Load the CSV and inspect structure
#
# Now add the following code cell below that markdown and run it.
#
# #### 1.1 Imports and file path

# %%
import pandas as pd
from pathlib import Path

# Set path to your CSV (adjust if needed)
data_path = Path("/Volumes/Personal Drive/GitHub/Proactive-Device-Quality-Signal-Detection/Dataset/Mobile Reviews Sentiment.csv")

# If you want to be extra safe, check that the file exists
data_path, data_path.exists()
# Out:
# (PosixPath('/Volumes/Personal Drive/GitHub/Proactive-Device-Quality-Signal-Detection/Dataset/Mobile Reviews Sentiment.csv'),
#  True)

# %% [markdown]
# #### 1.2 Read the CSV

# %%
# Read the raw CSV
df_raw = pd.read_csv(data_path)

# Show basic info
df_raw.shape
# Out:
# (50000, 25)

# %%
df_raw.head()
# Out:
#    review_id      customer_name  age     brand          model  price_usd  \
# 0          1      Aryan Maharaj   45    Realme  Realme 12 Pro     337.31
# 1          2  Davi Miguel Sousa   18    Realme  Realme 12 Pro     307.78
# 2          3        Pahal Balay   27    Google        Pixel 6     864.53
# 3          4       David Guzman   19    Xiaomi  Redmi Note 13     660.94
# 4          5          Yago Leão   38  Motorola        Edge 50     792.13
#
#   price_local currency  exchange_rate_to_usd  rating  ... verified_purchase  \
# 0   ₹27996.73      INR                 83.00       2  ...              True
# 1   R$1754.35      BRL                  5.70       4  ...              True
# 2   ₹71755.99      INR                 83.00       4  ...              True
# 3  د.إ2425.65      AED                  3.67       3  ...             False
# 4   R$4515.14      BRL                  5.70       3  ...              True
#
#   battery_life_rating camera_rating performance_rating design_rating  \
# 0                   1             1                  3             2
# 1                   3             2                  4             3
# 2                   3             5                  3             2
# 3                   1             3                  2             1
# 4                   3             3                  2             2
#
#    display_rating  review_length  word_count  helpful_votes      source
# 0               1             46           7              1      Amazon
# 1               2             74          12              5    Flipkart
# 2               4             55          11              8  AliExpress
# 3               2             66          11              3      Amazon
# 4               1             73          12              0     BestBuy
#
# [5 rows x 25 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   review_id             50000 non-null  int64
#  1   customer_name         50000 non-null  object
#  2   age                   50000 non-null  int64
#  3   brand                 50000 non-null  object
#  4   model                 50000 non-null  object
#  5   price_usd             50000 non-null  float64
#  6   price_local           50000 non-null  object
#  7   currency              50000 non-null  object
#  8   exchange_rate_to_usd  50000 non-null  float64
#  9   rating                50000 non-null  int64
#  10  review_text           50000 non-null  object
#  11  sentiment             50000 non-null  object
#  12  country               50000 non-null  object
#  13  language              50000 non-null  object
#  14  review_date           50000 non-null  object
#  15  verified_purchase     50000 non-null  bool
#  16  battery_life_rating   50000 non-null  int64
#  17  camera_rating         50000 non-null  int64
#  18  performance_rating    50000 non-null  int64
#  19  design_rating         50000 non-null  int64
#  20  display_rating        50000 non-null  int64
#  21  review_length         50000 non-null  int64
#  22  word_count            50000 non-null  int64
#  23  helpful_votes         50000 non-null  int64
#  24  source                50000 non-null  object
# dtypes: bool(1), float64(2), int64(11), object(11)
# memory usage: 9.2+ MB

# %%
df_raw.describe(include="all").T.head(20)
# Out:
#                         count unique  \
# review_id             50000.0    NaN
# customer_name           50000  45911
# age                   50000.0    NaN
# brand                   50000      7
# model                   50000     22
# price_usd             50000.0    NaN
# price_local             50000  48418
# currency                50000      8
# exchange_rate_to_usd  50000.0    NaN
# rating                50000.0    NaN
# review_text             50000    110
# sentiment               50000      3
# country                 50000      8
# language                50000      4
# review_date             50000   1096
# verified_purchase       50000      2
# battery_life_rating   50000.0    NaN
# camera_rating         50000.0    NaN
# performance_rating    50000.0    NaN
# design_rating         50000.0    NaN
#
#                                                                     top  \
# review_id                                                           NaN
# customer_name                                             Michael Smith
# age                                                                 NaN
# brand                                                            Xiaomi
# model                                                   Realme Narzo 70
# price_usd                                                           NaN
# price_local                                                    R$2272.3
# currency                                                            USD
# exchange_rate_to_usd                                                NaN
# rating                                                              NaN
# review_text           Design feels premium and stylish. Loving it so...
# sentiment                                                      Positive
# country                                                             USA
# language                                                        English
# review_date                                                  2023-04-05
# verified_purchase                                                  True
# battery_life_rating                                                 NaN
# camera_rating                                                       NaN
# performance_rating                                                  NaN
# design_rating                                                       NaN
#
#                        freq        mean           std     min       25%  \
# review_id               NaN     25000.5  14433.901067     1.0  12500.75
# customer_name            16         NaN           NaN     NaN       NaN
# age                     NaN    30.07522      8.931307    18.0      23.0
# brand                  7241         NaN           NaN     NaN       NaN
# model                  3597         NaN           NaN     NaN       NaN
# price_usd               NaN  689.693713    310.307331  180.02  450.7925
# price_local               4         NaN           NaN     NaN       NaN
# currency               6435         NaN           NaN     NaN       NaN
# exchange_rate_to_usd    NaN   12.057946     26.553332    0.78       1.0
# rating                  NaN     3.12312      1.248612     1.0       2.0
# review_text             724         NaN           NaN     NaN       NaN
# sentiment             27540         NaN           NaN     NaN       NaN
# country                6435         NaN           NaN     NaN       NaN
# language              31295         NaN           NaN     NaN       NaN
# review_date              67         NaN           NaN     NaN       NaN
# verified_purchase     40070         NaN           NaN     NaN       NaN
# battery_life_rating     NaN       2.718       1.34827     1.0       1.0
# camera_rating           NaN     2.71764      1.345001     1.0       1.0
# performance_rating      NaN     2.71962      1.349208     1.0       1.0
# design_rating           NaN     2.71396      1.343346     1.0       1.0
#
#                           50%       75%      max
# review_id             25000.5  37500.25  50000.0
# customer_name             NaN       NaN      NaN
# age                      29.0      36.0     65.0
# brand                     NaN       NaN      NaN
# model                     NaN       NaN      NaN
# price_usd              637.04   900.975  1499.89
# price_local               NaN       NaN      NaN
# currency                  NaN       NaN      NaN
# exchange_rate_to_usd     1.53       5.7     83.0
# rating                    3.0       4.0      5.0
# review_text               NaN       NaN      NaN
# sentiment                 NaN       NaN      NaN
# country                   NaN       NaN      NaN
# language                  NaN       NaN      NaN
# review_date               NaN       NaN      NaN
# verified_purchase         NaN       NaN      NaN
# battery_life_rating       3.0       4.0      5.0
# camera_rating             3.0       4.0      5.0
# performance_rating        3.0       4.0      5.0
# design_rating             3.0       4.0      5.0

# %% [markdown]
# ### 2. Standardize Key Columns & Basic Cleaning
#
# We rename key columns, parse dates, drop empty texts, and create a compact analysis-ready dataset.

# %%
# Copy the raw dataframe so we don’t modify df_raw directly
df = df_raw.copy()

# Rename columns we care about
rename_map = {
    "brand": "device_brand",
    "model": "device_model",
    "review_text": "review_text",
    "rating": "rating",
    "review_date": "review_date"
}

df = df.rename(columns=rename_map)

# Keep only the core columns we will use in signal detection
cols_to_keep = ["review_date", "device_brand", "device_model", "rating", "review_text"]
df = df[cols_to_keep].copy()

df.head()
# Out:
#   review_date device_brand   device_model  rating  \
# 0  2023-11-06       Realme  Realme 12 Pro       2
# 1  2023-03-30       Realme  Realme 12 Pro       4
# 2  2022-12-07       Google        Pixel 6       4
# 3  2025-03-11       Xiaomi  Redmi Note 13       3
# 4  2023-09-29     Motorola        Edge 50       3
#
#                                          review_text
# 0     Not worth the money spent. Wouldn’t recommend.
# 1  Absolutely love this phone! The camera is next...
# 2  Loving the clean UI and fast updates. Loving i...
# 3  Build quality feels solid and durable. No regr...
# 4  Not bad for daily use but could be optimized. ...

# %%
# Parse review_date into datetime
df["review_date"] = pd.to_datetime(df["review_date"], errors="coerce")

# Drop rows with missing date or missing/blank text
df = df.dropna(subset=["review_date", "review_text"])
df = df[df["review_text"].str.strip() != ""]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_date   50000 non-null  datetime64[ns]
#  1   device_brand  50000 non-null  object
#  2   device_model  50000 non-null  object
#  3   rating        50000 non-null  int64
#  4   review_text   50000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ### 3. Complaint Detection (Rule-Based)
#
# Here we create a simple `is_negative` / `is_complaint` flag using:
# - Star rating (<= 2 stars)
# - Presence of common issue keywords in the review text
#
# This gives us a first-pass "quality complaint" indicator for downstream aggregation and anomaly detection.

# %% [markdown]
# #### 3.1 Define keywords + helper function

# %%
import numpy as np

# Common device-quality complaint keywords/phrases
complaint_keywords = [
    "crash", "crashes", "crashing",
    "bug", "bugs", "glitch", "glitches",
    "lag", "laggy", "slow", "freezes", "freezing", "freeze",
    "overheat", "overheats", "overheating", "heats up",
    "battery drain", "battery dies", "poor battery", "bad battery",
    "random restart", "restarts", "reboot", "rebooting",
    "screen flicker", "screen issue", "display issue",
    "no signal", "network issue", "wifi issue", "wifi problem",
    "doesn't work", "doesnt work", "not working", "stopped working",
    "faulty", "defective", "problem with", "issue with"
]

def text_has_complaint_keywords(text: str) -> bool:
    """
    Returns True if the review text contains any of the complaint keywords.
    """
    if pd.isna(text):
        return False
    t = str(text).lower()
    return any(kw in t for kw in complaint_keywords)

# Apply keyword flag
df["has_complaint_kw"] = df["review_text"].apply(text_has_complaint_keywords)

df[["review_text", "has_complaint_kw"]].head(5)
# Out:
#                                          review_text  has_complaint_kw
# 0     Not worth the money spent. Wouldn’t recommend.             False
# 1  Absolutely love this phone! The camera is next...             False
# 2  Loving the clean UI and fast updates. Loving i...             False
# 3  Build quality feels solid and durable. No regr...             False
# 4  Not bad for daily use but could be optimized. ...             False

# %% [markdown]
# #### 3.2 Combine rating + keywords into `is_complaint`

# %%
# Make sure rating is numeric
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# Define complaint: low rating OR keyword hit
df["is_complaint"] = (
    (df["rating"] <= 2) | (df["has_complaint_kw"])
)

# Quick sanity checks
print("Total rows:", len(df))
print("Complaint rows:", df["is_complaint"].sum())
print("Complaint rate: {:.1%}".format(df["is_complaint"].mean()))

df[["rating", "has_complaint_kw", "is_complaint"]].head(10)
# Out:
# Total rows: 50000
# Complaint rows: 16581
# Complaint rate: 33.2%
#    rating  has_complaint_kw  is_complaint
# 0       2             False          True
# 1       4             False         False
# 2       4             False         False
# 3       3             False         False
# 4       3             False         False
# 5       5             False         False
# 6       3             False         False
# 7       2             False          True
# 8       4             False         False
# 9       3             False         False

# %% [markdown]
# #### 3.3 Peek at a few complaint vs non-complaint texts

# %%
print("=== Sample complaint reviews ===")
display(df[df["is_complaint"]].sample(5, random_state=42)[
    ["rating", "device_brand", "device_model", "review_text"]
])

print("=== Sample non-complaint reviews ===")
display(df[~df["is_complaint"]].sample(5, random_state=43)[
    ["rating", "device_brand", "device_model", "review_text"]
])
# Out:
# === Sample complaint reviews ===
#        rating device_brand   device_model  \
# 40074       2        Apple  iPhone 15 Pro
# 45746       2        Apple      iPhone 14
# 48840       2       Xiaomi  Redmi Note 13
# 9584        2       Xiaomi      Mi 13 Pro
# 47432       2      OnePlus     OnePlus 12
#
#                                              review_text
# 40074  Not bad for daily use but could be optimized. ...
# 45746  Overall decent, but expected a bit more for th...
# 48840  Design is okay, a bit bulky though. Average ex...
# 9584   Overheats quickly while gaming. Returning this...
# 47432  Sound quality is okay but not very loud. Fine ...
# === Sample non-complaint reviews ===
#        rating device_brand     device_model  \
# 18958       3       Xiaomi          Poco X6
# 31058       5        Apple        iPhone 14
# 25153       3       Realme  Realme Narzo 70
# 11460       3       Xiaomi    Redmi Note 13
# 41106       5      OnePlus   OnePlus Nord 3
#
#                                              review_text
# 18958  Battery easily lasts a day with heavy use. No ...
# 31058  Build quality feels solid and durable. Absolut...
# 25153  Loving the clean UI and fast updates. Loving i...
# 11460  Fast charging is a lifesaver. No regrets buyin...
# 41106  Design feels premium and stylish. Best purchas...

# %% [markdown]
# #### 3.4 Save this as our “clean + flagged” dataset

# %%
from pathlib import Path

clean_path = Path("/Volumes/Personal Drive/GitHub/Proactive-Device-Quality-Signal-Detection/Dataset/mobile_reviews_clean_flagged.csv")
df.to_csv(clean_path, index=False)

clean_path
# Out:
# PosixPath('/Volumes/Personal Drive/GitHub/Proactive-Device-Quality-Signal-Detection/Dataset/mobile_reviews_clean_flagged.csv')

# %% [markdown]
# ### 4. Weekly Aggregations for Quality Signal Detection
#
# We aggregate reviews by week and by (device_brand, device_model) to build
# a time-series dataset that captures complaint volume and complaint rate.
# This will be used for anomaly detection and Tableau dashboards.

# %% [markdown]
# #### 4.1 Extract “week start” date

# %%
# Create a "week_start" column (Monday of that week)
df["week_start"] = df["review_date"] - pd.to_timedelta(df["review_date"].dt.weekday, unit="D")

df[["review_date", "week_start"]].head()
# Out:
#   review_date week_start
# 0  2023-11-06 2023-11-06
# 1  2023-03-30 2023-03-27
# 2  2022-12-07 2022-12-05
# 3  2025-03-11 2025-03-10
# 4  2023-09-29 2023-09-25

# %% [markdown]
# #### 4.2 Weekly aggregation

# %%
weekly = (
    df.groupby(["device_brand", "device_model", "week_start"])
      .agg(
          total_reviews = ("review_text", "count"),
          total_complaints = ("is_complaint", "sum")
      )
      .reset_index()
)

# Complaint rate
weekly["complaint_rate"] = weekly["total_complaints"] / weekly["total_reviews"]

weekly.head(10)
# Out:
#   device_brand device_model week_start  total_reviews  total_complaints  \
# 0        Apple    iPhone 13 2022-10-17              1                 0
# 1        Apple    iPhone 13 2022-10-24             17                 2
# 2        Apple    iPhone 13 2022-10-31             11                 3
# 3        Apple    iPhone 13 2022-11-07             16                 5
# 4        Apple    iPhone 13 2022-11-14              9                 5
# 5        Apple    iPhone 13 2022-11-21              7                 3
# 6        Apple    iPhone 13 2022-11-28             12                 3
# 7        Apple    iPhone 13 2022-12-05              7                 2
# 8        Apple    iPhone 13 2022-12-12             12                 8
# 9        Apple    iPhone 13 2022-12-19             13                 2
#
#    complaint_rate
# 0        0.000000
# 1        0.117647
# 2        0.272727
# 3        0.312500
# 4        0.555556
# 5        0.428571
# 6        0.250000
# 7        0.285714
# 8        0.666667
# 9        0.153846

# %% [markdown]
# #### 4.3 Sanity check: how many weekly time-series do we have?

# %%
weekly.groupby(["device_brand", "device_model"]).size().sort_values(ascending=False).head(10)
# Out:
# device_brand  device_model
# Apple         iPhone 13          158
#               iPhone 14          158
# Xiaomi        Poco X6            158
#               Mi 13 Pro          158
# Samsung       Galaxy Z Flip      158
#               Galaxy S24         158
#               Galaxy A55         158
# Realme        Realme Narzo 70    158
#               Realme 12 Pro      158
# OnePlus       OnePlus Nord 3     158
# dtype: int64

# %% [markdown]
# #### 4.4 Optional: filter out models that have too few reviews

# %%
weekly = weekly[weekly["total_reviews"] >= 5]
weekly.shape
# Out:
# (3436, 6)

# %% [markdown]
# #### 4.5 Rolling metrics (for anomaly detection later)
#
# This prepares the data for the next step.

# %%
weekly = weekly.sort_values(["device_brand", "device_model", "week_start"])

# Rolling 6-week window (changeable)
weekly["roll_mean"] = (
    weekly.groupby(["device_brand", "device_model"])["complaint_rate"]
          .transform(lambda x: x.rolling(window=6, min_periods=3).mean())
)

weekly["roll_std"] = (
    weekly.groupby(["device_brand", "device_model"])["complaint_rate"]
          .transform(lambda x: x.rolling(window=6, min_periods=3).std())
)

weekly.head(10)
# Out:
#    device_brand device_model week_start  total_reviews  total_complaints  \
# 1         Apple    iPhone 13 2022-10-24             17                 2
# 2         Apple    iPhone 13 2022-10-31             11                 3
# 3         Apple    iPhone 13 2022-11-07             16                 5
# 4         Apple    iPhone 13 2022-11-14              9                 5
# 5         Apple    iPhone 13 2022-11-21              7                 3
# 6         Apple    iPhone 13 2022-11-28             12                 3
# 7         Apple    iPhone 13 2022-12-05              7                 2
# 8         Apple    iPhone 13 2022-12-12             12                 8
# 9         Apple    iPhone 13 2022-12-19             13                 2
# 10        Apple    iPhone 13 2022-12-26             11                 6
#
#     complaint_rate  roll_mean  roll_std
# 1         0.117647        NaN       NaN
# 2         0.272727        NaN       NaN
# 3         0.312500   0.234291  0.102956
# 4         0.555556   0.314607  0.181299
# 5         0.428571   0.337400  0.165074
# 6         0.250000   0.322834  0.151897
# 7         0.285714   0.350845  0.118264
# 8         0.666667   0.416501  0.165957
# 9         0.153846   0.390059  0.195798
# 10        0.545455   0.388376  0.194127

# %% [markdown]
# #### 4.6 Save the weekly dataset

# %%
weekly_path = Path("/Volumes/Personal Drive/GitHub/Proactive-Device-Quality-Signal-Detection/Dataset/weekly_complaint_timeseries.csv")
weekly.to_csv(weekly_path, index=False)

weekly_path
# Out:
# PosixPath('/Volumes/Personal Drive/GitHub/Proactive-Device-Quality-Signal-Detection/Dataset/weekly_complaint_timeseries.csv')
